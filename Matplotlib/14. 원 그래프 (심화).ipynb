# %% [markdown]
# # 14. 원 그래프 (심화)

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
values = [30, 25, 20, 13, 10, 2]
labels = ['Python', 'Java', 'Javascript', 'C#', 'C++', 'ETC']
# colors = ['b', 'g', 'r', 'c', 'm', 'y']
colors = ['#ffadad', '#ffd6a5', '#fdffb6', '#caffbf', '#9bf6ff', '#a0c4ff']
explode = [0.05] * 6

plt.pie(values, labels=labels, autopct='%.1f%%', counterclock=False, startangle=110, colors=colors, explode=explode)
plt.show()

# %%
wedgeprops = {'width':0.7}
plt.pie(values, labels=labels, autopct='%.1f%%', counterclock=False, startangle=110, colors=colors, explode=explode, wedgeprops=wedgeprops)
plt.show()

# %%
wedgeprops = {'width':0.7, 'edgecolor':'w', 'lw':2}
plt.pie(values, labels=labels, autopct='%.1f%%', counterclock=False, startangle=110, colors=colors, wedgeprops=wedgeprops)
plt.show()

# %%
def custom_autopct(pct):
    # return('%.1f%%' % pct) if pct >=10 else ''
    # return '{:.1f}%'.format(pct) if pct >= 10 else ''
    return '{:.0f}%'.format(pct) if pct >= 10 else ''

plt.pie(values, labels=labels, autopct=custom_autopct, counterclock=False, startangle=110, colors=colors, wedgeprops=wedgeprops, pctdistance=0.7)
plt.show()

# %% [markdown]
# ## DataFrame 활용

# %%
import pandas as pd

df = pd.read_excel('../Pandas/score.xlsx', index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  사회  과학        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  85  95      Python
# 2번    정대만  북산고  184   40   35   50  25  55        Java
# 3번    송태섭  북산고  168   80   75   70  75  80  Javascript
# 4번    서태웅  북산고  187   40   60   70  80  75         NaN
# 5번    강백호  북산고  188   15   20   10  10  35         NaN
# 6번    변덕규  능남고  202   80  100   95  80  85           C
# 7번    황태산  능남고  188   55   65   45  35  40      Python
# 8번    윤대형  능남고  190  100   85   90  95  95          C#

# %%
grp = df.groupby('학교')
grp

# %%
grp.size()
# Out:
# 학교
# 능남고    3
# 북산고    5
# dtype: int64

# %%
values = [grp.size()['북산고'], grp.size()['능남고']]
labels = ['북산고', '능남고']

wedgeprops = {'width':0.7, 'edgecolor':'w', 'lw':2}
colors = ['r', 'b']

plt.title('소속 학교')
plt.pie(values, labels=labels, autopct='%.1f%%', wedgeprops=wedgeprops, colors=colors)
plt.legend(loc=(1, 0.7), title='학교')
plt.show()
