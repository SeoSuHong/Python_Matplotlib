# %% [markdown]
# # 1-3. 인구 피라미드 (원 그래프)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 데이터 정의

# %%
file_name = '2022_연령별인구현황(원 그래프용).xlsx'
df = pd.read_excel(file_name, skiprows=3, index_col='행정기관', usecols='B, E:T')
df.head(3)
# Out:
# C:\Users\seosuhong\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#               0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국       1,516,736  2,219,906  2,365,898  2,340,104  3,106,678  3,526,033
# 서울특별시      242,264    337,488    367,847    387,176    600,767    816,614
# 부산광역시       87,059    131,449    133,439    132,605    193,584    219,978
#
#             30~34세     35~39세     40~44세     45~49세     50~54세     55~59세  \
# 행정기관
# 전국       3,221,121  3,483,150  4,002,922  4,163,901  4,533,423  4,101,632
# 서울특별시      737,570    699,687    731,205    748,654    803,416    703,551
# 부산광역시      194,917    209,162    249,861    252,378    284,130    269,730
#
#             60~64세     65~69세     70~74세     75~79세
# 행정기관
# 전국       4,150,307  3,045,996  2,119,409  1,605,485
# ...

# %%
df.iloc[0] = df.iloc[0].str.replace(',', '').astype(int)

# %%
df.iloc[0].head(3)
# Out:
# 0~4세      1516736
# 5~9세      2219906
# 10~14세    2365898
# Name: 전국  , dtype: object

# %% [markdown]
# ## 데이터 시각화

# %%
def people_pct(pct): # 4% 이하 데이터는 % 표시 안함
    return ('%.1f%%' % pct) if pct >= 4 else ''

plt.figure(figsize=(15, 10))
values = df.iloc[0]
labels = df.columns

wedgeprops = {'width':0.7, 'edgecolor':'w', 'lw':'1'}

plt.pie(values, labels=labels, startangle=90, counterclock=False, autopct=people_pct, wedgeprops=wedgeprops, pctdistance=0.8)
plt.title('2022년 대한민국 연령별 인구 분포도')
plt.legend(loc=(1.1, 0.2), title=('연령'))
plt.savefig('2022_인구피라미드(원 그래프).png', dpi=100)
plt.show()
